# %%
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from IPython import display
import numpy as np
import math as m
#%matplotlib inline

# %%
plt.plot([0, 159], [37012777.46, 105634845.9])
plt.grid(True)
plt.show()
